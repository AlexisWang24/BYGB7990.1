# %%
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
import json

# %%
atoken = "1186750374818078732-CXa6GhWLAk0K79bO3EuwYXss4YeLxN"
asecret = "ZaoF9wmiP9zhxNUJCpYBNitcanLTZ31Wka9vZhCIlNavH"
ckey = "IoGqQ42ZrscZXOmBSTC666TFq"
csecret = "PRhz7rwbBnkKUw5WrcnRr46NfIUtIYjRXj8L9rGnHlgcNrbd88"

# %%
class listener(StreamListener):
    def on_data(self, data):
        try:
            all_data = json.loads(data)

            tweet1 = all_data["text"]
            tweet = tweet1.encode('UTF-8')
            location = all_data["user"]["location"]
            #location = location1.encode('UTF-8')
            username = all_data["user"]["screen_name"]
            #username = username1.encode('UTF-8')
            
            followers_count = all_data["user"]["followers_count"]
            
           

            out = open('off-white.txt', 'a')
            out.write(str(username)+'::'+str(location)+'::'+str(followers_count)+'::'+str(tweet))
            out.write('\n')
            out.close()
            print (username, " :: ", tweet, " :: ",location," :: ",followers_count)
        except :
            print ('failed ondata')


    def on_error(self, status):
        print (status)

# %%
auth = OAuthHandler(ckey, csecret)
auth.set_access_token(atoken, asecret)
keywords = ["off-white"]
twitterStream = Stream(auth, listener())
twitterStream.filter(track=keywords, languages=["en"])
# Out:
# EBGPARIS  ::  b'all fly shit i used to go to school like this off-white kicks my shoe laces say \xe2\x80\x9cShoelaces\xe2\x80\x9d'  ::  Around  ::  841
# Suppjams  ::  b'awit \xf0\x9f\x94\xa5'  ::  Pasig City  ::  400
# VintageMontag3  ::  b'RT @Traptwinn: I got your b**** she off-white \xe2\x9d\x84\xef\xb8\x8f\xf0\x9f\xa7\xa2 https://t.co/sfenTHWITD'  ::  WhereEverYouPayMeToBe  ::  1820
# Terran12_  ::  b'PJ Tucker really hooped in some off-white airmax'  ::  huSTLe city - Chicago,IL  ::  1024
# ecbzxx  ::  b'RT @brkicks: PJ Tucker wearing the Off-White x Nike Air Max 90 against Portland. https://t.co/Mv6a58jbms'  ::  Portugal  ::  416
# emanueelmuniz  ::  b'RT @brkicks: PJ Tucker wearing the Off-White x Nike Air Max 90 against Portland. https://t.co/Mv6a58jbms'  ::  None  ::  1056
# ThatTrellGuy  ::  b'RT @brkicks: PJ Tucker wearing the Off-White x Nike Air Max 90 against Portland. https://t.co/Mv6a58jbms'  ::  Dallas, TX  ::  1488
# ...
